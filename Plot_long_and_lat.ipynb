# %%
import pandas as pd

def map_coordinates(csv_file):
    with open(csv_file, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            longitude = row['Longitude in km']
            latitude = row['Latitude in km']
            # Perform mapping or processing on longitude and latitude
            # Example: Print the coordinates
            print(f"Longitude: {longitude}, Latitude: {latitude}")

map_coordinates('/content/Merged_all.csv.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c466bfa61b07> in <cell line: 14>()
#      12
#      13 # Replace 'your_file.csv' with the actual path to your CSV file
# ---> 14 map_coordinates('/content/Merged_all.csv.csv')
#      15
#
# <ipython-input-1-c466bfa61b07> in map_coordinates(csv_file)
#       2
#       3 def map_coordinates(csv_file):
# ----> 4     with open(csv_file, 'r') as file:
#       5         reader = csv.DictReader(file)
#       6         for row in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Merged_all.csv.csv'

# %%
import csv
import matplotlib.pyplot as plt

def map_coordinates(csv_file):
    with open(csv_file, 'r') as file:
        reader = csv.DictReader(file)
        longitude_list = []
        latitude_list = []
        for row in reader:
            longitude = float(row['ADJ_LONGITUDE'])
            latitude = float(row['ADJ_LATITUDE'])
            longitude_list.append(longitude)
            latitude_list.append(latitude)

        plt.figure(figsize=(20, 20))

        # Plotting the coordinates
        plt.scatter(longitude_list, latitude_list)
        plt.xlabel('Longitude')
        plt.ylabel('Latitude')
        plt.title('Coordinate Plane')
        plt.show()

# Replace 'your_file.csv' with the actual path to your CSV file
map_coordinates('/content/Merged_all.csv')
